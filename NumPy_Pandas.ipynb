# %%
import pandas as pd
import numpy as np

# %%
marks = np.array([85,25, 35, 72, 68, 95, 70]) 
print("Original Array")
print(marks)
print("Slice (index 1 to 4):", marks[1:5])
# Out:
# Original Array
# [85 25 35 72 68 95 70]
# Slice (index 1 to 4): [25 35 72 68]

# %%
print("First mark:", marks[0])
# Out:
# First mark: 85

# %%
print("Last mark:", marks[-1])
# Out:
# Last mark: 70

# %%
print("First three marks:", marks[0:3])
# Out:
# First three marks: [85 25 35]

# %%
print("2 to 4 elements:", marks[2:5])
# Out:
# 2 to 4 elements: [35 72 68]

# %%
print("Every second mark:", marks[::2])
# Out:
# Every second mark: [85 35 68 70]

# %%
print("Reverse:", marks[::-1])
# Out:
# Reverse: [70 95 68 72 35 25 85]

# %%
dat = np.array([
    [85, 78, 90],
    [72, 80, 75],
    [90, 87, 95]
])
print(dat)
# Out:
# [[85 78 90]
#  [72 80 75]
#  [90 87 95]]

# %%
d = {
    "Name": ["Janaki", "Vrushika", "Snehal", "Shikha"],
    "Marks": [92, 74, 85, 63],
    "Branch": ["ISE", "CSE", "AI", "ECE"]
}
data = pd.DataFrame(d)
print(data)
# Out:
#        Name  Marks Branch
# 0    Janaki     92    ISE
# 1  Vrushika     74    CSE
# 2    Snehal     85     AI
# 3    Shikha     63    ECE

# %%
print("First 2 Rows\n", data.iloc[:2])
# Out:
# First 2 Rows
#         Name  Marks Branch
# 0    Janaki     92    ISE
# 1  Vrushika     74    CSE

# %%
print(data.iloc[-1])
# Out:
# Name      Shikha
# Marks         63
# Branch       ECE
# Name: 3, dtype: object

# %%
print(data.iloc[1:3])
# Out:
#        Name  Marks Branch
# 1  Vrushika     74    CSE
# 2    Snehal     85     AI

# %%
print("Marks Column:\n", data["Marks"])
# Out:
# Marks Column:
#  0    92
# 1    74
# 2    85
# 3    63
# Name: Marks, dtype: int64

# %%
print("Rows where Marks > 70:\n", data[data["Marks"] > 70])
# Out:
# Rows where Marks > 70:
#         Name  Marks Branch
# 0    Janaki     92    ISE
# 1  Vrushika     74    CSE
# 2    Snehal     85     AI
